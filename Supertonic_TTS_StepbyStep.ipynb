# %% [markdown]
# ## Text Encoder

# %%
# %%bash
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-onnx-converter \
#     --input_network ./assets/onnx/text_encoder.onnx \
#     --input_dim text_ids 1,128 \
#     --input_dim style_ttl 1,50,256 \
#     --input_dim text_mask 1,1,128 \
#     --output_path ./QNN_Models/text_encoder_htp.cpp \
#     --input_list ./qnn_calibration/text_encoder/input_list.txt
# Out:
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:17:20,092 - 278 - INFO - Input shape info
# 2026-01-24 22:17:23,106 - 388 - WARNING - unsupported broadcast between 4 Pad_161_o0__d0
# 2026-01-24 22:17:23,107 - 283 - WARNING - Symbolic shape inference Failed. Exception: Incomplete symbolic shape inference.. Running normal shape inference.
# WARNING: The argument `input_shapes` is deprecated. Please use
# `overwrite_input_shapes` and/or `test_input_shapes` instead. An error will be
# raised in the future.
# 2026-01-24 22:17:26,121 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Equal Not Supported. Expected operator version: [1, 7, 11, 13], instead got version: [19]
# 2026-01-24 22:17:26,124 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Equal Not Supported. Expected operator version: [1, 7, 11, 13], instead got version: [19]
# 2026-01-24 22:17:26,263 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,265 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,267 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,279 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,282 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,294 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,297 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,306 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,333 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,334 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,336 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,348 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,351 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,362 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,366 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,374 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,402 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,404 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,407 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,418 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,422 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,433 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,437 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,445 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,472 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,474 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,476 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,487 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,491 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,502 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,507 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:26,515 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:17:28,092 - 283 - WARNING - Op /text_encoder/text_embedder/Mul with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
#      0.5ms [  INFO ] Inferences will run in sync mode
# Processing inference input(s):
# ./qnn_calibration/text_encoder/text_ids_100.raw
# ./qnn_calibration/text_encoder/style_ttl_100.raw
# ./qnn_calibration/text_encoder/text_mask_100.raw
#      0.6ms [  INFO ] Initializing logging in the backend. Callback: [0x7415f022aff0], Log Level: [3]
#      0.6ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation start
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation end
#      0.9ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.9ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create start
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create end
#      1.1ms [  INFO ] Entering QuantizeRuntimeApp flow
#      1.1ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.5ms [  INFO ] [QNN_CPU] CpuGraph creation start
#      0.5ms [  INFO ] [QNN_CPU] CpuGraph creation end
#      0.5ms [  INFO ] [QNN_CPU] QnnGraph create end
#      1.3ms [WARNING] Output[0] has Datatype 0x232.
#
#      1.4ms [WARNING] Output[0] has Datatype 0x232.
#
#      2.7ms [WARNING] Output[0] has Datatype 0x232.
#
#      2.8ms [WARNING] Output[0] has Datatype 0x232.
#
#     45.6ms [  INFO ] [QNN_CPU] QnnGraph finalize start
#     69.7ms [  INFO ] [QNN_CPU] QnnGraph finalize end
#     73.7ms [  INFO ] [QNN_CPU] QnnGraph execute start
#    432.3ms [  INFO ] [QNN_CPU] QnnGraph execute end
#    432.0ms [  INFO ] cleaning up resources for input tensors
#    432.0ms [  INFO ] cleaning up resources for output tensors
#    498.0ms [  INFO ] Freeing graphsInfo
#    498.0ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#    498.5ms [  INFO ] [QNN_CPU] QnnContext Free start
#    501.2ms [  INFO ] [QNN_CPU] QnnContext Free end
#    500.9ms [WARNING] Profile Logger with name = defaultKey doesn't exist!
#    501.5ms [  INFO ] [QNN_CPU] QnnBackend Free start
#    501.5ms [  INFO ] [QNN_CPU] QnnBackend Free end
# 2026-01-24 22:17:30,977 - 278 - INFO - Saving QNN Model...
# 2026-01-24 22:17:31,027 - 278 - INFO - Model CPP saved at: ./QNN_Models/text_encoder_htp.cpp
# 2026-01-24 22:17:31,028 - 278 - INFO - Model BIN saved at: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Models/text_encoder_htp.bin
# 2026-01-24 22:17:31,040 - 278 - INFO - Conversion complete!

# %%
# %%bash
# unset LD_LIBRARY_PATH
# source /home/cto/qcom-wayland_sdk/environment-setup-armv8-2a-qcom-linux
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-model-lib-generator \
#     -c ./QNN_Models/text_encoder_htp.cpp \
#     -b ./QNN_Models/text_encoder_htp.bin \
#     -o ./QNN_Model_lib/ \
#     -t aarch64-oe-linux-gcc11.2
# Out:
# SDK environment now set up; additionally you may now run devtool to perform development tasks.
# Run devtool --help for further details.
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:18:22,558 -    INFO - qnn-model-lib-generator: Model cpp file path  : QNN_Models/text_encoder_htp.cpp
# 2026-01-24 22:18:22,559 -    INFO - qnn-model-lib-generator: Model bin file path  : QNN_Models/text_encoder_htp.bin
# 2026-01-24 22:18:22,559 -    INFO - qnn-model-lib-generator: Library target       : [['aarch64-oe-linux-gcc11.2']]
# 2026-01-24 22:18:22,559 -    INFO - qnn-model-lib-generator: Library name         : text_encoder_htp
# 2026-01-24 22:18:22,559 -    INFO - qnn-model-lib-generator: Output directory     : QNN_Model_lib
# 2026-01-24 22:18:22,559 -    INFO - qnn-model-lib-generator: Output library name  : text_encoder_htp
# 2026-01-24 22:18:58,794 -    INFO - qnn-model-lib-generator: Target: aarch64-oe-linux-gcc11.2	Library: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Model_lib/aarch64-oe-linux-gcc11.2/libtext_encoder_htp.so

# %% [markdown]
# ## Vocoder

# %%
# %%bash
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-onnx-converter \
#     --input_network ./assets/onnx/vocoder.onnx \
#     --input_dim latent 1,144,256 \
#     --output_path ./QNN_Models/vocoder_htp.cpp \
#     --input_list ./qnn_calibration/vocoder/input_list.txt
# Out:
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:18:59,686 - 278 - INFO - Input shape info
# WARNING: The argument `input_shapes` is deprecated. Please use
# `overwrite_input_shapes` and/or `test_input_shapes` instead. An error will be
# raised in the future.
# 2026-01-24 22:19:07,749 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:19:07,753 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:19:08,017 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation PRelu Not Supported. Expected operator version: [1, 6, 7, 9], instead got version: [16]
# 2026-01-24 22:19:08,027 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
#      0.2ms [  INFO ] Inferences will run in sync mode
# Processing inference input(s):
# ./qnn_calibration/vocoder/latent_100.raw
#      0.3ms [  INFO ] Initializing logging in the backend. Callback: [0x793e04e2aff0], Log Level: [3]
#      0.3ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation start
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation end
#      0.6ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.6ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create start
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create end
#      0.8ms [  INFO ] Entering QuantizeRuntimeApp flow
#      0.8ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.5ms [  INFO ] [QNN_CPU] CpuGraph creation start
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation end
#      0.6ms [  INFO ] [QNN_CPU] QnnGraph create end
#     85.5ms [  INFO ] [QNN_CPU] QnnGraph finalize start
#    167.7ms [  INFO ] [QNN_CPU] QnnGraph finalize end
#    168.3ms [  INFO ] [QNN_CPU] QnnGraph execute start
#   3891.6ms [  INFO ] [QNN_CPU] QnnGraph execute end
#   3894.1ms [  INFO ] cleaning up resources for input tensors
#   3894.2ms [  INFO ] cleaning up resources for output tensors
#   4052.9ms [  INFO ] Freeing graphsInfo
#   4053.0ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#   4053.5ms [  INFO ] [QNN_CPU] QnnContext Free start
#   4054.7ms [  INFO ] [QNN_CPU] QnnContext Free end
#   4054.6ms [WARNING] Profile Logger with name = defaultKey doesn't exist!
#   4055.2ms [  INFO ] [QNN_CPU] QnnBackend Free start
#   4055.2ms [  INFO ] [QNN_CPU] QnnBackend Free end
# 2026-01-24 22:19:14,523 - 278 - INFO - Saving QNN Model...
# 2026-01-24 22:19:14,577 - 278 - INFO - Model CPP saved at: ./QNN_Models/vocoder_htp.cpp
# 2026-01-24 22:19:14,577 - 278 - INFO - Model BIN saved at: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Models/vocoder_htp.bin
# 2026-01-24 22:19:14,583 - 278 - INFO - Conversion complete!

# %%
# %%bash
# unset LD_LIBRARY_PATH
# source /home/cto/qcom-wayland_sdk/environment-setup-armv8-2a-qcom-linux
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-model-lib-generator \
#     -c ./QNN_Models/vocoder_htp.cpp \
#     -b ./QNN_Models/vocoder_htp.bin \
#     -o ./QNN_Model_lib/ \
#     -t aarch64-oe-linux-gcc11.2
# Out:
# SDK environment now set up; additionally you may now run devtool to perform development tasks.
# Run devtool --help for further details.
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Model cpp file path  : QNN_Models/vocoder_htp.cpp
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Model bin file path  : QNN_Models/vocoder_htp.bin
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Library target       : [['aarch64-oe-linux-gcc11.2']]
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Library name         : vocoder_htp
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Output directory     : QNN_Model_lib
# 2026-01-24 22:19:14,894 -    INFO - qnn-model-lib-generator: Output library name  : vocoder_htp
# 2026-01-24 22:19:32,156 -    INFO - qnn-model-lib-generator: Target: aarch64-oe-linux-gcc11.2	Library: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Model_lib/aarch64-oe-linux-gcc11.2/libvocoder_htp.so

# %% [markdown]
# ## Duration Predictor

# %%
# %%bash
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-onnx-converter \
#     --input_network ./assets/onnx/duration_predictor.onnx \
#     --input_dim text_ids 1,128 \
#     --input_dim style_dp 1,8,16 \
#     --input_dim text_mask 1,1,128 \
#     --output_path ./QNN_Models/duration_predictor_htp.cpp \
#     --input_list ./qnn_calibration/duration_predictor/input_list.txt
# Out:
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:21:37,780 - 278 - INFO - Input shape info
# 2026-01-24 22:21:40,601 - 388 - WARNING - unsupported broadcast between 2 Pad_164_o0__d0
# 2026-01-24 22:21:40,601 - 283 - WARNING - Symbolic shape inference Failed. Exception: Incomplete symbolic shape inference.. Running normal shape inference.
# WARNING: The argument `input_shapes` is deprecated. Please use
# `overwrite_input_shapes` and/or `test_input_shapes` instead. An error will be
# raised in the future.
# 2026-01-24 22:21:42,086 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,096 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Equal Not Supported. Expected operator version: [1, 7, 11, 13], instead got version: [19]
# 2026-01-24 22:21:42,214 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,216 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,218 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,230 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,234 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,245 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,249 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,257 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,282 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,284 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,286 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,298 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,302 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,312 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,316 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,325 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,353 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:21:42,356 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-01-24 22:21:42,359 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation PRelu Not Supported. Expected operator version: [1, 6, 7, 9], instead got version: [16]
# 2026-01-24 22:21:42,362 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-01-24 22:21:43,215 - 283 - WARNING - Op /sentence_encoder/text_embedder/Mul with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
#      0.2ms [  INFO ] Inferences will run in sync mode
# Processing inference input(s):
# ./qnn_calibration/duration_predictor/text_ids_100.raw
# ./qnn_calibration/duration_predictor/style_dp_100.raw
# ./qnn_calibration/duration_predictor/text_mask_100.raw
#      0.3ms [  INFO ] Initializing logging in the backend. Callback: [0x731a3282aff0], Log Level: [3]
#      0.3ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation start
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation end
#      0.6ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.6ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create start
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create end
#      0.9ms [  INFO ] Entering QuantizeRuntimeApp flow
#      0.9ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation start
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation end
#      0.6ms [  INFO ] [QNN_CPU] QnnGraph create end
#      0.8ms [WARNING] Output[0] has Datatype 0x232.
#
#      0.9ms [WARNING] Output[0] has Datatype 0x232.
#
#     14.3ms [  INFO ] [QNN_CPU] QnnGraph finalize start
#     17.0ms [  INFO ] [QNN_CPU] QnnGraph finalize end
#     20.4ms [  INFO ] [QNN_CPU] QnnGraph execute start
#    120.4ms [  INFO ] [QNN_CPU] QnnGraph execute end
#    119.9ms [  INFO ] cleaning up resources for input tensors
#    119.9ms [  INFO ] cleaning up resources for output tensors
#    140.5ms [  INFO ] Freeing graphsInfo
#    140.5ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#    141.1ms [  INFO ] [QNN_CPU] QnnContext Free start
#    142.7ms [  INFO ] [QNN_CPU] QnnContext Free end
#    142.5ms [WARNING] Profile Logger with name = defaultKey doesn't exist!
#    143.1ms [  INFO ] [QNN_CPU] QnnBackend Free start
#    143.1ms [  INFO ] [QNN_CPU] QnnBackend Free end
# 2026-01-24 22:21:44,839 - 278 - INFO - Saving QNN Model...
# 2026-01-24 22:21:44,873 - 278 - INFO - Model CPP saved at: ./QNN_Models/duration_predictor_htp.cpp
# 2026-01-24 22:21:44,874 - 278 - INFO - Model BIN saved at: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Models/duration_predictor_htp.bin
# 2026-01-24 22:21:44,881 - 278 - INFO - Conversion complete!

# %%
# %%bash
# unset LD_LIBRARY_PATH
# source /home/cto/qcom-wayland_sdk/environment-setup-armv8-2a-qcom-linux
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-model-lib-generator \
#     -c ./QNN_Models/duration_predictor_htp.cpp \
#     -b ./QNN_Models/duration_predictor_htp.bin \
#     -o ./QNN_Model_lib/ \
#     -t aarch64-oe-linux-gcc11.2
# Out:
# SDK environment now set up; additionally you may now run devtool to perform development tasks.
# Run devtool --help for further details.
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:22:17,686 -    INFO - qnn-model-lib-generator: Model cpp file path  : QNN_Models/duration_predictor_htp.cpp
# 2026-01-24 22:22:17,687 -    INFO - qnn-model-lib-generator: Model bin file path  : QNN_Models/duration_predictor_htp.bin
# 2026-01-24 22:22:17,687 -    INFO - qnn-model-lib-generator: Library target       : [['aarch64-oe-linux-gcc11.2']]
# 2026-01-24 22:22:17,687 -    INFO - qnn-model-lib-generator: Library name         : duration_predictor_htp
# 2026-01-24 22:22:17,687 -    INFO - qnn-model-lib-generator: Output directory     : QNN_Model_lib
# 2026-01-24 22:22:17,687 -    INFO - qnn-model-lib-generator: Output library name  : duration_predictor_htp
# 2026-01-24 22:22:37,911 -    INFO - qnn-model-lib-generator: Target: aarch64-oe-linux-gcc11.2	Library: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Model_lib/aarch64-oe-linux-gcc11.2/libduration_predictor_htp.so

# %% [markdown]
# ## vector Esimator

# %%
# %%bash
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-onnx-converter \
#     --input_network ./assets/onnx/vector_estimator.onnx \
#     --input_dim noisy_latent 1,144,256 \
#     --input_dim text_emb 1,256,128 \
#     --input_dim style_ttl 1,50,256 \
#     --input_dim latent_mask 1,1,256 \
#     --input_dim text_mask 1,1,128 \
#     --input_dim current_step 1 \
#     --input_dim total_step 1 \
#     --output_path ./QNN_Models/vector_estimator_htp.cpp \
#     --input_list ./qnn_calibration/vector_estimator/input_list.txt
# Out:
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:22:38,778 - 278 - INFO - Input shape info
# WARNING: The argument `input_shapes` is deprecated. Please use
# `overwrite_input_shapes` and/or `test_input_shapes` instead. An error will be
# raised in the future.
# 2026-01-24 22:22:48,605 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:22:48,607 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:22:48,635 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reciprocal Not Supported. Expected operator version: [1, 6], instead got version: [13]
# 2026-01-24 22:22:48,639 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:22:48,641 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:22:48,646 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Equal Not Supported. Expected operator version: [1, 7, 11, 13], instead got version: [19]
# 2026-01-24 22:22:48,663 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Reshape Not Supported. Expected operator version: [1, 5, 13, 14], instead got version: [19]
# 2026-01-24 22:22:48,669 - 283 - WARNING - WARNING_OP_VERSION_NOT_SUPPORTED: Operation Equal Not Supported. Expected operator version: [1, 7, 11, 13], instead got version: [19]
# 2026-01-24 22:22:48,797 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-01-24 22:22:48,833 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-01-24 22:22:53,612 - 283 - WARNING - Op /vector_field/main_blocks.1/Add with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
# 2026-01-24 22:22:53,836 - 283 - WARNING - Op /vector_field/main_blocks.7/Add with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
# 2026-01-24 22:22:54,058 - 283 - WARNING - Op /vector_field/main_blocks.13/Add with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
# 2026-01-24 22:22:54,277 - 283 - WARNING - Op /vector_field/main_blocks.19/Add with input_buf axis format NONTRIVIAL and data_axis_format NCF is no need to revert.
#      1.1ms [  INFO ] Inferences will run in sync mode
# Processing inference input(s):
# ./qnn_calibration/vector_estimator/noisy_latent_100.raw
# ./qnn_calibration/vector_estimator/text_emb_100.raw
# ./qnn_calibration/vector_estimator/style_ttl_100.raw
# ./qnn_calibration/vector_estimator/latent_mask_100.raw
# ./qnn_calibration/vector_estimator/text_mask_100.raw
# ./qnn_calibration/vector_estimator/current_step_100.raw
# ./qnn_calibration/vector_estimator/total_step_100.raw
#      1.2ms [  INFO ] Initializing logging in the backend. Callback: [0x75d2b002aff0], Log Level: [3]
#      1.2ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation start
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation end
#      1.5ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      1.5ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create start
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create end
#      1.7ms [  INFO ] Entering QuantizeRuntimeApp flow
#      1.7ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation start
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation end
#      0.6ms [  INFO ] [QNN_CPU] QnnGraph create end
#      3.4ms [WARNING] Output[0] has Datatype 0x232.
#
#      3.4ms [WARNING] Output[0] has Datatype 0x232.
#
#      5.7ms [WARNING] Output[0] has Datatype 0x232.
#
#      5.7ms [WARNING] Output[0] has Datatype 0x232.
#
#    156.8ms [  INFO ] [QNN_CPU] QnnGraph finalize start
#    266.5ms [  INFO ] [QNN_CPU] QnnGraph finalize end
#    276.0ms [  INFO ] [QNN_CPU] QnnGraph execute start
#   1497.7ms [  INFO ] [QNN_CPU] QnnGraph execute end
#   1497.3ms [  INFO ] cleaning up resources for input tensors
#   1497.3ms [  INFO ] cleaning up resources for output tensors
#   1747.8ms [  INFO ] Freeing graphsInfo
#   1747.8ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#   1748.4ms [  INFO ] [QNN_CPU] QnnContext Free start
#   1754.9ms [  INFO ] [QNN_CPU] QnnContext Free end
#   1754.6ms [WARNING] Profile Logger with name = defaultKey doesn't exist!
#   1755.2ms [  INFO ] [QNN_CPU] QnnBackend Free start
#   1755.2ms [  INFO ] [QNN_CPU] QnnBackend Free end
# 2026-01-24 22:23:00,471 - 278 - INFO - Saving QNN Model...
# 2026-01-24 22:23:00,607 - 278 - INFO - Model CPP saved at: ./QNN_Models/vector_estimator_htp.cpp
# 2026-01-24 22:23:00,607 - 278 - INFO - Model BIN saved at: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Models/vector_estimator_htp.bin
# 2026-01-24 22:23:00,635 - 278 - INFO - Conversion complete!

# %%
# %%bash
# unset LD_LIBRARY_PATH
# source /home/cto/qcom-wayland_sdk/environment-setup-armv8-2a-qcom-linux
# source /opt/qcom/aistack/qairt/2.37.1.250807/bin/envsetup.sh
#
# qnn-model-lib-generator \
#     -c ./QNN_Models/vector_estimator_htp.cpp \
#     -b ./QNN_Models/vector_estimator_htp.bin \
#     -o ./QNN_Model_lib/ \
#     -t aarch64-oe-linux-gcc11.2
# Out:
# SDK environment now set up; additionally you may now run devtool to perform development tasks.
# Run devtool --help for further details.
# [INFO] QAIRT_SDK_ROOT=/opt/qcom/aistack/qairt/2.37.1.250807
# [WARN] QNN_SDK_ROOT/SNPE_ROOT set to QAIRT_SDK_ROOT for backwards compatibility and will be deprecated in a future release.
# [INFO] QAIRT SDK environment setup complete
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Model cpp file path  : QNN_Models/vector_estimator_htp.cpp
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Model bin file path  : QNN_Models/vector_estimator_htp.bin
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Library target       : [['aarch64-oe-linux-gcc11.2']]
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Library name         : vector_estimator_htp
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Output directory     : QNN_Model_lib
# 2026-01-24 22:23:00,960 -    INFO - qnn-model-lib-generator: Output library name  : vector_estimator_htp
# 2026-01-24 22:25:25,304 -    INFO - qnn-model-lib-generator: Target: aarch64-oe-linux-gcc11.2	Library: /home/cto/indispeaks/supertonic_htp_Testing/QNN_Model_lib/aarch64-oe-linux-gcc11.2/libvector_estimator_htp.so
